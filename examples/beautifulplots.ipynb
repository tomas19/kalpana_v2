# %% [markdown]
# ## Specific Site Plot Samples <br>
# Created by Brandon Tucker in 2023 <br>
# <br>
# More examples showcasing the vis_mesh at specific sites. <br>
# These functions are explained in export_example03.

# %%
import os
import sys

### import Kalpana functions from github repository
# sys.path.append(r'C:/Users/brand/Github/Kalpana')
from export import fort14togdf
from visualizations import vis_mesh

# %% [markdown]
# **The following cell runs fort14togdf() and stores the output as a geodataframe.** <br>

# %%
os.getcwd()
# Out:
# '/home/tomas/github/Kalpana/examples'

# %%
## path of the input fort 14 file
filein = r'../adds/inputs_examples/fort.14'

## coordinate system of the fort14 input
epsgIn = 4326

## coordinate system of the output shapefile
epsgOut = 4326

## call fort14togdf() to create a geodataframe object
gdf = fort14togdf(filein, epsgIn, epsgOut, fileintype='fort.14')

# %% [markdown]
# **The following cells create visualizations topography and bathymetry elevations at specific locations.** <br>
# They may take a while to generate.

# %%
# North Carolina Elevations

# define a figure and axis
fig, ax = plt.subplots(figsize = (8,6), nrows = 1, ncols = 1, subplot_kw={'projection': ccrs.PlateCarree()}, constrained_layout=True)

# visualize the mesh and the colorbar based on elevation (zmean) in the NC bounds
vis_mesh(gdf, 'zmean', xylims = [-78.5, -75, 33.5, 37], ax = ax, fig = fig, cbar_label = 'Elevation [m MSL]', vmin = -4000,
         ticks = [-4000, -3000, -2000, -1000, 0, 10, 20, 30], background_map = False)
fig.suptitle('North Carolina - Element Elevations', fontsize = 16)
# Out:
# Text(0.5, 0.98, 'North Carolina - Element Elevations')

# %%
# Carolina Beach

# define a figure and axis
fig, ax = plt.subplots(figsize = (8,6), nrows = 1, ncols = 1, subplot_kw={'projection': ccrs.PlateCarree()}, constrained_layout=True)

# visualize the mesh and the colorbar based on elevation (zmean) in the NC bounds
vis_mesh(gdf, 'zmean', xylims = [-78.25, -77.75, 33.75, 34.25], ax = ax, fig = fig, cbar_label = 'Elevation [m MSL]', vmin = -30, background_map = False)
fig.suptitle('Carolina Beach Element Elevations', fontsize = 16)
# Out:
# Text(0.5, 0.98, 'Carolina Beach Element Elevations')

# %%
# Pamlico River

# define a figure and axis
fig, ax = plt.subplots(figsize = (8,6), nrows = 1, ncols = 1, subplot_kw={'projection': ccrs.PlateCarree()}, constrained_layout=True)

# visualize the mesh and the colorbar based on elevation (zmean) in the NC bounds
vis_mesh(gdf, 'zmean', xylims = [-76.9, -76.1, 35.1, 35.9], ax = ax, fig = fig, cbar_label = 'Elevation [m MSL]', vmin = -25, background_map = False)
fig.suptitle('Pamlico River Element Elevations', fontsize = 16)
# Out:
# Text(0.5, 0.98, 'Pamlico River Element Elevations')

# %%
# New River

# define a figure and axis
fig, ax = plt.subplots(figsize = (8,6), nrows = 1, ncols = 1, subplot_kw={'projection': ccrs.PlateCarree()}, constrained_layout=True)

# visualize the mesh and the colorbar based on elevation (zmean) in the NC bounds
vis_mesh(gdf, 'zmean', xylims = [-77.6, -76.8, 34.3, 35.1], ax = ax, fig = fig, cbar_label = 'Elevation [m MSL]', vmin = -50, background_map = False)
fig.suptitle('New River Element Elevations', fontsize = 16)
# Out:
# Text(0.5, 0.98, 'New River Element Elevations')
